# %%
import openpyxl
from openai import OpenAI
import os
import time
import json

# Initialize OpenAI client
client = OpenAI(api_key="")  # Replace with your API key

def get_completion(prompt, model="gpt-3.5-turbo-1106", retries=3):
    for _ in range(retries):
        try:
            messages = [{"role": "system", "content": "You are designed to output the final answer in JSON."},
                        {"role": "user", "content": prompt}]
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0,
                response_format={"type": "json_object"}
            )
            return response.choices[0].message.content
        except Exception as e:
            print(f"An error occurred: {e}. Retrying...")
            time.sleep(2)
    return None

# Workbook path
wb_path = 'C:/Work/Articles/Chat-GPT/specializeddoc/Osteoarthritis/Part1.Base model evaluation/Retrieval/treatment_retrieval_oldones_newstructure.xlsx'
wb = openpyxl.load_workbook(wb_path)
sheet = wb['Sheet1']

# Define the user-defined start row
user_defined_start_row = 2

# Mapping of input columns to their corresponding output columns
column_mapping = {
    'Retrieval1': 'Response1',
    'Retrieval2': 'Response2',
    'Retrieval3': 'Response3',
    'Retrieval4': 'Response4',
    'Retrieval5': 'Response5'
}

# Determine column indices once before the loop (Change)
column_indices = {col[0].value: col[0].column for col in sheet.iter_cols(1, sheet.max_column)}

# Checkpoint handling
try:
    with open("checkpoint.json", "r") as f:
        checkpoint = json.load(f)
    checkpoint_start_row = checkpoint["row"]
except FileNotFoundError:
    checkpoint_start_row = 2

# Determine the starting row
start_row = max(user_defined_start_row, checkpoint_start_row)
print(f"Starting from row {start_row}...")

# Your existing prompt text
prompt = """
 Read the information regarding suggestions for osteoarthritis.
 You should summarize the suggestions about what the intervention is, whether or not the intervention is recommended, if any, the strength of this recommendation (if specified), and the level of certainty of the evidence supporting it (if specified). 
 You should always provide answer based on the given information, you must never hallucinate, 
 Format the infomation into json format according to the following example:
 
 Example in json format：Intervention: AA ;RecommendationStatus: EE;StrengthOfRecommendation: BB;LevelOfCertainty: CC；Source: DD

"""

stop_script = False

for content_row in range(start_row, sheet.max_row + 1):
    if stop_script:
        break

    for input_column, output_column in column_mapping.items():
        input_col_index = column_indices.get(input_column)  # Retrieve column index from dictionary (Change)
        output_col_index = column_indices.get(output_column)  # Retrieve column index from dictionary (Change)

        if input_col_index is None or output_col_index is None:
            print(f"Column {input_column} or {output_column} not found.")
            continue

        content = sheet.cell(row=content_row, column=input_col_index).value
        if content is None:
            continue

        print(f"Processing row {content_row}, column {input_column}...")

        full_prompt = f"{prompt} {content}"
        response = get_completion(full_prompt)

        if response is None:
            with open("checkpoint.json", "w") as f:
                json.dump({"row": content_row}, f)
            print(f"Stopping at row {content_row}. Checkpoint saved.")
            stop_script = True
            break

        sheet.cell(row=content_row, column=output_col_index).value = response.strip()

    wb.save(wb_path)
    print(f"Saved data for row {content_row}")

if os.path.exists("checkpoint.json"):
    os.remove("checkpoint.json")

print("The task has been successfully completed.")
# Out:
# Starting from row 2...
# Processing row 2, column Retrieval2...
# Processing row 2, column Retrieval3...
# Processing row 2, column Retrieval4...
# Processing row 2, column Retrieval5...
# Saved data for row 2
# Processing row 3, column Retrieval1...
# Processing row 3, column Retrieval2...
# Processing row 3, column Retrieval3...
# Processing row 3, column Retrieval4...
# Processing row 3, column Retrieval5...
# Saved data for row 3
# Processing row 4, column Retrieval1...
# Processing row 4, column Retrieval2...
# Processing row 4, column Retrieval3...
# Processing row 4, column Retrieval4...
# Processing row 4, column Retrieval5...
# Saved data for row 4
# Processing row 5, column Retrieval1...
# Processing row 5, column Retrieval2...
# Processing row 5, column Retrieval3...
# Processing row 5, column Retrieval4...
# Processing row 5, column Retrieval5...
# Saved data for row 5
# Processing row 6, column Retrieval1...
# Processing row 6, column Retrieval2...
# Processing row 6, column Retrieval3...
# Processing row 6, column Retrieval4...
# Processing row 6, column Retrieval5...
# Saved data for row 6
# Processing row 7, column Retrieval1...
# Processing row 7, column Retrieval2...
# Processing row 7, column Retrieval3...
# Processing row 7, column Retrieval4...
# Processing row 7, column Retrieval5...
# Saved data for row 7
# Processing row 8, column Retrieval1...
# Processing row 8, column Retrieval2...
# Processing row 8, column Retrieval3...
# Processing row 8, column Retrieval4...
# Processing row 8, column Retrieval5...
# Saved data for row 8
# Processing row 9, column Retrieval1...
# Processing row 9, column Retrieval2...
# Processing row 9, column Retrieval3...
# Processing row 9, column Retrieval4...
# Processing row 9, column Retrieval5...
# Saved data for row 9
# Processing row 10, column Retrieval1...
# Processing row 10, column Retrieval2...
# Processing row 10, column Retrieval3...
# Processing row 10, column Retrieval4...
# Processing row 10, column Retrieval5...
# Saved data for row 10
# Processing row 11, column Retrieval1...
# Processing row 11, column Retrieval2...
# Processing row 11, column Retrieval3...
# Processing row 11, column Retrieval4...
# Processing row 11, column Retrieval5...
# Saved data for row 11
# Processing row 12, column Retrieval1...
# Processing row 12, column Retrieval2...
# Processing row 12, column Retrieval3...
# Processing row 12, column Retrieval4...
# Processing row 12, column Retrieval5...
# Saved data for row 12
# Processing row 13, column Retrieval1...
# Processing row 13, column Retrieval2...
# Processing row 13, column Retrieval3...
# Processing row 13, column Retrieval4...
# Processing row 13, column Retrieval5...
# Saved data for row 13
# Processing row 14, column Retrieval1...
# Processing row 14, column Retrieval2...
# Processing row 14, column Retrieval3...
# Processing row 14, column Retrieval4...
# Processing row 14, column Retrieval5...
# Saved data for row 14
# Processing row 15, column Retrieval1...
# Processing row 15, column Retrieval2...
# Processing row 15, column Retrieval3...
# Processing row 15, column Retrieval4...
# Processing row 15, column Retrieval5...
# Saved data for row 15
# Processing row 16, column Retrieval1...
# Processing row 16, column Retrieval2...
# Processing row 16, column Retrieval3...
# Processing row 16, column Retrieval4...
# Processing row 16, column Retrieval5...
# Saved data for row 16
# Processing row 17, column Retrieval1...
# Processing row 17, column Retrieval2...
# Processing row 17, column Retrieval3...
# Processing row 17, column Retrieval4...
# Processing row 17, column Retrieval5...
# Saved data for row 17
# Processing row 18, column Retrieval1...
# Processing row 18, column Retrieval2...
# Processing row 18, column Retrieval3...
# Processing row 18, column Retrieval4...
# Processing row 18, column Retrieval5...
# Saved data for row 18
# Processing row 19, column Retrieval1...
# Processing row 19, column Retrieval2...
# Processing row 19, column Retrieval3...
# Processing row 19, column Retrieval4...
# Processing row 19, column Retrieval5...
# Saved data for row 19
# Processing row 20, column Retrieval1...
# Processing row 20, column Retrieval2...
# Processing row 20, column Retrieval3...
# Processing row 20, column Retrieval4...
# Processing row 20, column Retrieval5...
# Saved data for row 20
# Processing row 21, column Retrieval1...
# Processing row 21, column Retrieval2...
# Processing row 21, column Retrieval3...
# Processing row 21, column Retrieval4...
# Processing row 21, column Retrieval5...
# Saved data for row 21
# Processing row 22, column Retrieval1...
# Processing row 22, column Retrieval2...
# Processing row 22, column Retrieval3...
# Processing row 22, column Retrieval4...
# Processing row 22, column Retrieval5...
# Saved data for row 22
# Processing row 23, column Retrieval1...
# Processing row 23, column Retrieval2...
# Processing row 23, column Retrieval3...
# Processing row 23, column Retrieval4...
# Processing row 23, column Retrieval5...
# Saved data for row 23
# Processing row 24, column Retrieval1...
# Processing row 24, column Retrieval2...
# Processing row 24, column Retrieval3...
# Processing row 24, column Retrieval4...
# Processing row 24, column Retrieval5...
# Saved data for row 24
# Processing row 25, column Retrieval1...
# Processing row 25, column Retrieval2...
# Processing row 25, column Retrieval3...
# Processing row 25, column Retrieval4...
# Processing row 25, column Retrieval5...
# Saved data for row 25
# Processing row 26, column Retrieval1...
# Processing row 26, column Retrieval2...
# Processing row 26, column Retrieval3...
# Processing row 26, column Retrieval4...
# Processing row 26, column Retrieval5...
# Saved data for row 26
# Processing row 27, column Retrieval1...
# Processing row 27, column Retrieval2...
# Processing row 27, column Retrieval3...
# Processing row 27, column Retrieval4...
# Processing row 27, column Retrieval5...
# Saved data for row 27
# Processing row 28, column Retrieval1...
# Processing row 28, column Retrieval2...
# Processing row 28, column Retrieval3...
# Processing row 28, column Retrieval4...
# Processing row 28, column Retrieval5...
# Saved data for row 28
# Processing row 29, column Retrieval1...
# Processing row 29, column Retrieval2...
# Processing row 29, column Retrieval3...
# Processing row 29, column Retrieval4...
# Processing row 29, column Retrieval5...
# Saved data for row 29
# Processing row 30, column Retrieval1...
# Processing row 30, column Retrieval2...
# Processing row 30, column Retrieval3...
# Processing row 30, column Retrieval4...
# Processing row 30, column Retrieval5...
# Saved data for row 30
# Processing row 31, column Retrieval1...
# Processing row 31, column Retrieval2...
# Processing row 31, column Retrieval3...
# Processing row 31, column Retrieval4...
# Processing row 31, column Retrieval5...
# Saved data for row 31
# Processing row 32, column Retrieval1...
# Processing row 32, column Retrieval2...
# Processing row 32, column Retrieval3...
# Processing row 32, column Retrieval4...
# Processing row 32, column Retrieval5...
# Saved data for row 32
# Processing row 33, column Retrieval1...
# Processing row 33, column Retrieval2...
# Processing row 33, column Retrieval3...
# Processing row 33, column Retrieval4...
# Processing row 33, column Retrieval5...
# Saved data for row 33
# Processing row 34, column Retrieval1...
# Processing row 34, column Retrieval2...
# Processing row 34, column Retrieval3...
# Processing row 34, column Retrieval4...
# Processing row 34, column Retrieval5...
# Saved data for row 34
# Processing row 35, column Retrieval1...
# Processing row 35, column Retrieval2...
# Processing row 35, column Retrieval3...
# Processing row 35, column Retrieval4...
# Processing row 35, column Retrieval5...
# Saved data for row 35
# Processing row 36, column Retrieval1...
# Processing row 36, column Retrieval2...
# Processing row 36, column Retrieval3...
# Processing row 36, column Retrieval4...
# Processing row 36, column Retrieval5...
# Saved data for row 36
# Processing row 37, column Retrieval1...
# Processing row 37, column Retrieval2...
# Processing row 37, column Retrieval3...
# Processing row 37, column Retrieval4...
# Processing row 37, column Retrieval5...
# Saved data for row 37
# Processing row 38, column Retrieval1...
# Processing row 38, column Retrieval2...
# Processing row 38, column Retrieval3...
# Processing row 38, column Retrieval4...
# Processing row 38, column Retrieval5...
# Saved data for row 38
# Processing row 39, column Retrieval1...
# Processing row 39, column Retrieval2...
# Processing row 39, column Retrieval3...
# Processing row 39, column Retrieval4...
# Processing row 39, column Retrieval5...
# Saved data for row 39
# Processing row 40, column Retrieval1...
# Processing row 40, column Retrieval2...
# Processing row 40, column Retrieval3...
# Processing row 40, column Retrieval4...
# Processing row 40, column Retrieval5...
# Saved data for row 40
# Processing row 41, column Retrieval1...
# Processing row 41, column Retrieval2...
# Processing row 41, column Retrieval3...
# Processing row 41, column Retrieval4...
# Processing row 41, column Retrieval5...
# Saved data for row 41
# Processing row 42, column Retrieval1...
# Processing row 42, column Retrieval2...
# Processing row 42, column Retrieval3...
# Processing row 42, column Retrieval4...
# Processing row 42, column Retrieval5...
# Saved data for row 42
# Processing row 43, column Retrieval1...
# Processing row 43, column Retrieval2...
# Processing row 43, column Retrieval3...
# Processing row 43, column Retrieval4...
# Processing row 43, column Retrieval5...
# Saved data for row 43
# Processing row 44, column Retrieval1...
# Processing row 44, column Retrieval2...
# Processing row 44, column Retrieval3...
# Processing row 44, column Retrieval4...
# Processing row 44, column Retrieval5...
# Saved data for row 44
# Processing row 45, column Retrieval1...
# Processing row 45, column Retrieval2...
# Processing row 45, column Retrieval3...
# Processing row 45, column Retrieval4...
# Processing row 45, column Retrieval5...
# Saved data for row 45
# Processing row 46, column Retrieval1...
# Processing row 46, column Retrieval2...
# Processing row 46, column Retrieval3...
# Processing row 46, column Retrieval4...
# Processing row 46, column Retrieval5...
# Saved data for row 46
# Processing row 47, column Retrieval1...
# Processing row 47, column Retrieval2...
# Processing row 47, column Retrieval3...
# Processing row 47, column Retrieval4...
# Processing row 47, column Retrieval5...
# Saved data for row 47
# Processing row 48, column Retrieval1...
# Processing row 48, column Retrieval2...
# Processing row 48, column Retrieval3...
# Processing row 48, column Retrieval4...
# Processing row 48, column Retrieval5...
# Saved data for row 48
# Processing row 49, column Retrieval1...
# Processing row 49, column Retrieval2...
# Processing row 49, column Retrieval3...
# Processing row 49, column Retrieval4...
# Processing row 49, column Retrieval5...
# Saved data for row 49
# Processing row 50, column Retrieval1...
# Processing row 50, column Retrieval2...
# Processing row 50, column Retrieval3...
# Processing row 50, column Retrieval4...
# Processing row 50, column Retrieval5...
# Saved data for row 50
# Processing row 51, column Retrieval1...
# Processing row 51, column Retrieval2...
# Processing row 51, column Retrieval3...
# Processing row 51, column Retrieval4...
# Processing row 51, column Retrieval5...
# Saved data for row 51
# Processing row 52, column Retrieval1...
# Processing row 52, column Retrieval2...
# Processing row 52, column Retrieval3...
# Processing row 52, column Retrieval4...
# Processing row 52, column Retrieval5...
# Saved data for row 52
# Processing row 53, column Retrieval1...
# Processing row 53, column Retrieval2...
# Processing row 53, column Retrieval3...
# Processing row 53, column Retrieval4...
# Processing row 53, column Retrieval5...
# Saved data for row 53
# Processing row 54, column Retrieval1...
# Processing row 54, column Retrieval2...
# Processing row 54, column Retrieval3...
# Processing row 54, column Retrieval4...
# Processing row 54, column Retrieval5...
# Saved data for row 54
# Processing row 55, column Retrieval1...
# Processing row 55, column Retrieval2...
# Processing row 55, column Retrieval3...
# Processing row 55, column Retrieval4...
# Processing row 55, column Retrieval5...
# Saved data for row 55
# Processing row 56, column Retrieval1...
# Processing row 56, column Retrieval2...
# Processing row 56, column Retrieval3...
# Processing row 56, column Retrieval4...
# Processing row 56, column Retrieval5...
# Saved data for row 56
# Processing row 57, column Retrieval1...
# Processing row 57, column Retrieval2...
# Processing row 57, column Retrieval3...
# Processing row 57, column Retrieval4...
# Processing row 57, column Retrieval5...
# Saved data for row 57
# Processing row 58, column Retrieval1...
# Processing row 58, column Retrieval2...
# Processing row 58, column Retrieval3...
# Processing row 58, column Retrieval4...
# Processing row 58, column Retrieval5...
# Saved data for row 58
# Processing row 59, column Retrieval1...
# Processing row 59, column Retrieval2...
# Processing row 59, column Retrieval3...
# Processing row 59, column Retrieval4...
# Processing row 59, column Retrieval5...
# Saved data for row 59
# Processing row 60, column Retrieval1...
# Processing row 60, column Retrieval2...
# Processing row 60, column Retrieval3...
# Processing row 60, column Retrieval4...
# Processing row 60, column Retrieval5...
# Saved data for row 60
# Processing row 61, column Retrieval1...
# Processing row 61, column Retrieval2...
# Processing row 61, column Retrieval3...
# Processing row 61, column Retrieval4...
# Processing row 61, column Retrieval5...
# Saved data for row 61
# Processing row 62, column Retrieval1...
# Processing row 62, column Retrieval2...
# Processing row 62, column Retrieval3...
# Processing row 62, column Retrieval4...
# Processing row 62, column Retrieval5...
# Saved data for row 62
# Processing row 63, column Retrieval1...
# Processing row 63, column Retrieval2...
# Processing row 63, column Retrieval3...
# Processing row 63, column Retrieval4...
# Processing row 63, column Retrieval5...
# Saved data for row 63
# Processing row 64, column Retrieval1...
# Processing row 64, column Retrieval2...
# Processing row 64, column Retrieval3...
# Processing row 64, column Retrieval4...
# Processing row 64, column Retrieval5...
# Saved data for row 64
# Processing row 65, column Retrieval1...
# Processing row 65, column Retrieval2...
# Processing row 65, column Retrieval3...
# Processing row 65, column Retrieval4...
# Processing row 65, column Retrieval5...
# Saved data for row 65
# Processing row 66, column Retrieval1...
# Processing row 66, column Retrieval2...
# Processing row 66, column Retrieval3...
# Processing row 66, column Retrieval4...
# Processing row 66, column Retrieval5...
# Saved data for row 66
# Processing row 67, column Retrieval1...
# Processing row 67, column Retrieval2...
# Processing row 67, column Retrieval3...
# Processing row 67, column Retrieval4...
# Processing row 67, column Retrieval5...
# Saved data for row 67
# Processing row 68, column Retrieval1...
# Processing row 68, column Retrieval2...
# Processing row 68, column Retrieval3...
# Processing row 68, column Retrieval4...
# Processing row 68, column Retrieval5...
# Saved data for row 68
# Processing row 69, column Retrieval1...
# Processing row 69, column Retrieval2...
# Processing row 69, column Retrieval3...
# Processing row 69, column Retrieval4...
# Processing row 69, column Retrieval5...
# Saved data for row 69
# Processing row 70, column Retrieval1...
# Processing row 70, column Retrieval2...
# Processing row 70, column Retrieval3...
# Processing row 70, column Retrieval4...
# Processing row 70, column Retrieval5...
# Saved data for row 70
# Processing row 71, column Retrieval1...
# Processing row 71, column Retrieval2...
# Processing row 71, column Retrieval3...
# Processing row 71, column Retrieval4...
# Processing row 71, column Retrieval5...
# Saved data for row 71
# Processing row 72, column Retrieval1...
# Processing row 72, column Retrieval2...
# Processing row 72, column Retrieval3...
# Processing row 72, column Retrieval4...
# Processing row 72, column Retrieval5...
# Saved data for row 72
# Processing row 73, column Retrieval1...
# Processing row 73, column Retrieval2...
# Processing row 73, column Retrieval3...
# Processing row 73, column Retrieval4...
# Processing row 73, column Retrieval5...
# Saved data for row 73
# Processing row 74, column Retrieval1...
# Processing row 74, column Retrieval2...
# Processing row 74, column Retrieval3...
# Processing row 74, column Retrieval4...
# Processing row 74, column Retrieval5...
# Saved data for row 74
# Processing row 75, column Retrieval1...
# Processing row 75, column Retrieval2...
# Processing row 75, column Retrieval3...
# Processing row 75, column Retrieval4...
# Processing row 75, column Retrieval5...
# Saved data for row 75
# Processing row 76, column Retrieval1...
# Processing row 76, column Retrieval2...
# Processing row 76, column Retrieval3...
# Processing row 76, column Retrieval4...
# Processing row 76, column Retrieval5...
# Saved data for row 76
# Processing row 77, column Retrieval1...
# Processing row 77, column Retrieval2...
# Processing row 77, column Retrieval3...
# Processing row 77, column Retrieval4...
# Processing row 77, column Retrieval5...
# Saved data for row 77
# Processing row 78, column Retrieval1...
# Processing row 78, column Retrieval2...
# Processing row 78, column Retrieval3...
# Processing row 78, column Retrieval4...
# Processing row 78, column Retrieval5...
# Saved data for row 78
# Processing row 79, column Retrieval1...
# Processing row 79, column Retrieval2...
# Processing row 79, column Retrieval3...
# Processing row 79, column Retrieval4...
# Processing row 79, column Retrieval5...
# Saved data for row 79
# Processing row 80, column Retrieval1...
# Processing row 80, column Retrieval2...
# Processing row 80, column Retrieval3...
# Processing row 80, column Retrieval4...
# Processing row 80, column Retrieval5...
# Saved data for row 80
# Processing row 81, column Retrieval1...
# Processing row 81, column Retrieval2...
# Processing row 81, column Retrieval3...
# Processing row 81, column Retrieval4...
# Processing row 81, column Retrieval5...
# Saved data for row 81
# Processing row 82, column Retrieval1...
# Processing row 82, column Retrieval2...
# Processing row 82, column Retrieval3...
# Processing row 82, column Retrieval4...
# Processing row 82, column Retrieval5...
# Saved data for row 82
# Processing row 83, column Retrieval1...
# Processing row 83, column Retrieval2...
# Processing row 83, column Retrieval3...
# Processing row 83, column Retrieval4...
# Processing row 83, column Retrieval5...
# Saved data for row 83
# Processing row 84, column Retrieval1...
# Processing row 84, column Retrieval2...
# Processing row 84, column Retrieval3...
# Processing row 84, column Retrieval4...
# Processing row 84, column Retrieval5...
# Saved data for row 84
# Processing row 85, column Retrieval1...
# Processing row 85, column Retrieval2...
# Processing row 85, column Retrieval3...
# Processing row 85, column Retrieval4...
# Processing row 85, column Retrieval5...
# Saved data for row 85
# Processing row 86, column Retrieval1...
# Processing row 86, column Retrieval2...
# Processing row 86, column Retrieval3...
# Processing row 86, column Retrieval4...
# Processing row 86, column Retrieval5...
# Saved data for row 86
# Processing row 87, column Retrieval1...
# Processing row 87, column Retrieval2...
# Processing row 87, column Retrieval3...
# Processing row 87, column Retrieval4...
# Processing row 87, column Retrieval5...
# Saved data for row 87
# Processing row 88, column Retrieval1...
# Processing row 88, column Retrieval2...
# Processing row 88, column Retrieval3...
# Processing row 88, column Retrieval4...
# Processing row 88, column Retrieval5...
# Saved data for row 88
# Processing row 89, column Retrieval1...
# Processing row 89, column Retrieval2...
# Processing row 89, column Retrieval3...
# Processing row 89, column Retrieval4...
# Processing row 89, column Retrieval5...
# Saved data for row 89
# Processing row 90, column Retrieval1...
# Processing row 90, column Retrieval2...
# Processing row 90, column Retrieval3...
# Processing row 90, column Retrieval4...
# Processing row 90, column Retrieval5...
# Saved data for row 90
# Processing row 91, column Retrieval1...
# Processing row 91, column Retrieval2...
# Processing row 91, column Retrieval3...
# Processing row 91, column Retrieval4...
# Processing row 91, column Retrieval5...
# Saved data for row 91
# Processing row 92, column Retrieval1...
# Processing row 92, column Retrieval2...
# Processing row 92, column Retrieval3...
# Processing row 92, column Retrieval4...
# Processing row 92, column Retrieval5...
# Saved data for row 92
# Processing row 93, column Retrieval1...
# Processing row 93, column Retrieval2...
# Processing row 93, column Retrieval3...
# Processing row 93, column Retrieval4...
# Processing row 93, column Retrieval5...
# Saved data for row 93
# Processing row 94, column Retrieval1...
# Processing row 94, column Retrieval2...
# Processing row 94, column Retrieval3...
# Processing row 94, column Retrieval4...
# Processing row 94, column Retrieval5...
# Saved data for row 94
# Processing row 95, column Retrieval1...
# Processing row 95, column Retrieval2...
# Processing row 95, column Retrieval3...
# Processing row 95, column Retrieval4...
# Processing row 95, column Retrieval5...
# Saved data for row 95
# Processing row 96, column Retrieval1...
# Processing row 96, column Retrieval2...
# Processing row 96, column Retrieval3...
# Processing row 96, column Retrieval4...
# Processing row 96, column Retrieval5...
# Saved data for row 96
# Processing row 97, column Retrieval1...
# Processing row 97, column Retrieval2...
# Processing row 97, column Retrieval3...
# Processing row 97, column Retrieval4...
# Processing row 97, column Retrieval5...
# Saved data for row 97
# Processing row 98, column Retrieval1...
# Processing row 98, column Retrieval2...
# Processing row 98, column Retrieval3...
# Processing row 98, column Retrieval4...
# Processing row 98, column Retrieval5...
# Saved data for row 98
# Processing row 99, column Retrieval1...
# Processing row 99, column Retrieval2...
# Processing row 99, column Retrieval3...
# Processing row 99, column Retrieval4...
# Processing row 99, column Retrieval5...
# Saved data for row 99
# Processing row 100, column Retrieval1...
# Processing row 100, column Retrieval2...
# Processing row 100, column Retrieval3...
# Processing row 100, column Retrieval4...
# Processing row 100, column Retrieval5...
# Saved data for row 100
# Processing row 101, column Retrieval1...
# Processing row 101, column Retrieval2...
# Processing row 101, column Retrieval3...
# Processing row 101, column Retrieval4...
# Processing row 101, column Retrieval5...
# Saved data for row 101
# Processing row 102, column Retrieval1...
# Processing row 102, column Retrieval2...
# Processing row 102, column Retrieval3...
# Processing row 102, column Retrieval4...
# Processing row 102, column Retrieval5...
# Saved data for row 102
# Processing row 103, column Retrieval1...
# Processing row 103, column Retrieval2...
# Processing row 103, column Retrieval3...
# Processing row 103, column Retrieval4...
# Processing row 103, column Retrieval5...
# Saved data for row 103
# Processing row 104, column Retrieval1...
# Processing row 104, column Retrieval2...
# Processing row 104, column Retrieval3...
# Processing row 104, column Retrieval4...
# Processing row 104, column Retrieval5...
# Saved data for row 104
# Processing row 105, column Retrieval1...
# Processing row 105, column Retrieval2...
# Processing row 105, column Retrieval3...
# Processing row 105, column Retrieval4...
# Processing row 105, column Retrieval5...
# Saved data for row 105
# Processing row 106, column Retrieval1...
# Processing row 106, column Retrieval2...
# Processing row 106, column Retrieval3...
# Processing row 106, column Retrieval4...
# Processing row 106, column Retrieval5...
# Saved data for row 106
# Processing row 107, column Retrieval1...
# Processing row 107, column Retrieval2...
# Processing row 107, column Retrieval3...
# Processing row 107, column Retrieval4...
# Processing row 107, column Retrieval5...
# Saved data for row 107
# Processing row 108, column Retrieval1...
# Processing row 108, column Retrieval2...
# Processing row 108, column Retrieval3...
# Processing row 108, column Retrieval4...
# Processing row 108, column Retrieval5...
# Saved data for row 108
# Processing row 109, column Retrieval1...
# Processing row 109, column Retrieval2...
# Processing row 109, column Retrieval3...
# Processing row 109, column Retrieval4...
# Processing row 109, column Retrieval5...
# Saved data for row 109
# Processing row 110, column Retrieval1...
# Processing row 110, column Retrieval2...
# Processing row 110, column Retrieval3...
# Processing row 110, column Retrieval4...
# Processing row 110, column Retrieval5...
# Saved data for row 110
# Processing row 111, column Retrieval1...
# Processing row 111, column Retrieval2...
# Processing row 111, column Retrieval3...
# Processing row 111, column Retrieval4...
# Processing row 111, column Retrieval5...
# Saved data for row 111
# Processing row 112, column Retrieval1...
# Processing row 112, column Retrieval2...
# Processing row 112, column Retrieval3...
# Processing row 112, column Retrieval4...
# Processing row 112, column Retrieval5...
# Saved data for row 112
# Processing row 113, column Retrieval1...
# Processing row 113, column Retrieval2...
# Processing row 113, column Retrieval3...
# Processing row 113, column Retrieval4...
# Processing row 113, column Retrieval5...
# Saved data for row 113
# Processing row 114, column Retrieval1...
# Processing row 114, column Retrieval2...
# Processing row 114, column Retrieval3...
# Processing row 114, column Retrieval4...
# Processing row 114, column Retrieval5...
# Saved data for row 114
# Processing row 115, column Retrieval1...
# Processing row 115, column Retrieval2...
# Processing row 115, column Retrieval3...
# Processing row 115, column Retrieval4...
# Processing row 115, column Retrieval5...
# Saved data for row 115
# Processing row 116, column Retrieval1...
# Processing row 116, column Retrieval2...
# Processing row 116, column Retrieval3...
# Processing row 116, column Retrieval4...
# Processing row 116, column Retrieval5...
# Saved data for row 116
# Processing row 117, column Retrieval1...
# Processing row 117, column Retrieval2...
# Processing row 117, column Retrieval3...
# Processing row 117, column Retrieval4...
# Processing row 117, column Retrieval5...
# Saved data for row 117
# Processing row 118, column Retrieval1...
# Processing row 118, column Retrieval2...
# Processing row 118, column Retrieval3...
# Processing row 118, column Retrieval4...
# Processing row 118, column Retrieval5...
# Saved data for row 118
# Processing row 119, column Retrieval1...
# Processing row 119, column Retrieval2...
# Processing row 119, column Retrieval3...
# Processing row 119, column Retrieval4...
# Processing row 119, column Retrieval5...
# Saved data for row 119
# Processing row 120, column Retrieval1...
# Processing row 120, column Retrieval2...
# Processing row 120, column Retrieval3...
# Processing row 120, column Retrieval4...
# Processing row 120, column Retrieval5...
# Saved data for row 120
# Processing row 121, column Retrieval1...
# Processing row 121, column Retrieval2...
# Processing row 121, column Retrieval3...
# Processing row 121, column Retrieval4...
# Processing row 121, column Retrieval5...
# Saved data for row 121
# Processing row 122, column Retrieval1...
# Processing row 122, column Retrieval2...
# Processing row 122, column Retrieval3...
# Processing row 122, column Retrieval4...
# Processing row 122, column Retrieval5...
# Saved data for row 122
# Processing row 123, column Retrieval1...
# Processing row 123, column Retrieval2...
# Processing row 123, column Retrieval3...
# Processing row 123, column Retrieval4...
# Processing row 123, column Retrieval5...
# Saved data for row 123
# Processing row 124, column Retrieval1...
# Processing row 124, column Retrieval2...
# Processing row 124, column Retrieval3...
# Processing row 124, column Retrieval4...
# Processing row 124, column Retrieval5...
# Saved data for row 124
# Processing row 125, column Retrieval1...
# Processing row 125, column Retrieval2...
# Processing row 125, column Retrieval3...
# Processing row 125, column Retrieval4...
# Processing row 125, column Retrieval5...
# Saved data for row 125
# Processing row 126, column Retrieval1...
# Processing row 126, column Retrieval2...
# Processing row 126, column Retrieval3...
# Processing row 126, column Retrieval4...
# Processing row 126, column Retrieval5...
# Saved data for row 126
# Processing row 127, column Retrieval1...
# Processing row 127, column Retrieval2...
# Processing row 127, column Retrieval3...
# Processing row 127, column Retrieval4...
# Processing row 127, column Retrieval5...
# Saved data for row 127
# Processing row 128, column Retrieval1...
# Processing row 128, column Retrieval2...
# Processing row 128, column Retrieval3...
# Processing row 128, column Retrieval4...
# Processing row 128, column Retrieval5...
# Saved data for row 128
# Processing row 129, column Retrieval1...
# Processing row 129, column Retrieval2...
# Processing row 129, column Retrieval3...
# Processing row 129, column Retrieval4...
# Processing row 129, column Retrieval5...
# Saved data for row 129
# Processing row 130, column Retrieval1...
# Processing row 130, column Retrieval2...
# Processing row 130, column Retrieval3...
# Processing row 130, column Retrieval4...
# Processing row 130, column Retrieval5...
# Saved data for row 130
# Processing row 131, column Retrieval1...
# Processing row 131, column Retrieval2...
# Processing row 131, column Retrieval3...
# Processing row 131, column Retrieval4...
# Processing row 131, column Retrieval5...
# Saved data for row 131
# Processing row 132, column Retrieval1...
# Processing row 132, column Retrieval2...
# Processing row 132, column Retrieval3...
# Processing row 132, column Retrieval4...
# Processing row 132, column Retrieval5...
# Saved data for row 132
# Processing row 133, column Retrieval1...
# Processing row 133, column Retrieval2...
# Processing row 133, column Retrieval3...
# Processing row 133, column Retrieval4...
# Processing row 133, column Retrieval5...
# Saved data for row 133
# Processing row 134, column Retrieval1...
# Processing row 134, column Retrieval2...
# Processing row 134, column Retrieval3...
# Processing row 134, column Retrieval4...
# Processing row 134, column Retrieval5...
# Saved data for row 134
# Processing row 135, column Retrieval1...
# Processing row 135, column Retrieval2...
# Processing row 135, column Retrieval3...
# Processing row 135, column Retrieval4...
# Processing row 135, column Retrieval5...
# Saved data for row 135
# Processing row 136, column Retrieval1...
# Processing row 136, column Retrieval2...
# Processing row 136, column Retrieval3...
# Processing row 136, column Retrieval4...
# Processing row 136, column Retrieval5...
# Saved data for row 136
# Processing row 137, column Retrieval1...
# Processing row 137, column Retrieval2...
# Processing row 137, column Retrieval3...
# Processing row 137, column Retrieval4...
# Processing row 137, column Retrieval5...
# Saved data for row 137
# Processing row 138, column Retrieval1...
# Processing row 138, column Retrieval2...
# Processing row 138, column Retrieval3...
# Processing row 138, column Retrieval4...
# Processing row 138, column Retrieval5...
# Saved data for row 138
# Processing row 139, column Retrieval1...
# Processing row 139, column Retrieval2...
# Processing row 139, column Retrieval3...
# Processing row 139, column Retrieval4...
# Processing row 139, column Retrieval5...
# Saved data for row 139
# Processing row 140, column Retrieval1...
# Processing row 140, column Retrieval2...
# Processing row 140, column Retrieval3...
# Processing row 140, column Retrieval4...
# Processing row 140, column Retrieval5...
# Saved data for row 140
# Processing row 141, column Retrieval1...
# Processing row 141, column Retrieval2...
# Processing row 141, column Retrieval3...
# Processing row 141, column Retrieval4...
# Processing row 141, column Retrieval5...
# Saved data for row 141
# Processing row 142, column Retrieval1...
# Processing row 142, column Retrieval2...
# Processing row 142, column Retrieval3...
# Processing row 142, column Retrieval4...
# Processing row 142, column Retrieval5...
# Saved data for row 142
# Processing row 143, column Retrieval1...
# Processing row 143, column Retrieval2...
# Processing row 143, column Retrieval3...
# Processing row 143, column Retrieval4...
# Processing row 143, column Retrieval5...
# Saved data for row 143
# Processing row 144, column Retrieval1...
# Processing row 144, column Retrieval2...
# Processing row 144, column Retrieval3...
# Processing row 144, column Retrieval4...
# Processing row 144, column Retrieval5...
# Saved data for row 144
# Processing row 145, column Retrieval1...
# Processing row 145, column Retrieval2...
# Processing row 145, column Retrieval3...
# Processing row 145, column Retrieval4...
# Processing row 145, column Retrieval5...
# Saved data for row 145
# Processing row 146, column Retrieval1...
# Processing row 146, column Retrieval2...
# Processing row 146, column Retrieval3...
# Processing row 146, column Retrieval4...
# Processing row 146, column Retrieval5...
# Saved data for row 146
# The task has been successfully completed.
